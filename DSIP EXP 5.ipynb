# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       import numpy as np
import matplotlib.pyplot as plt

def DFT(x):
    """Compute the discrete Fourier Transform of the 1D array x"""
    N = len(x)
    X = np.zeros(N, dtype=complex)
    for k in range(N):
        for n in range(N):
            X[k] += x[n] * np.exp(-2j * np.pi * k * n / N)
    return X

# Get input from the user
n = int(input("Enter the number of elements: "))
x = []
print("Enter the elements:")
for i in range(n):
  temp = int(input())
  x.append(temp)

x = np.array(x)
X = DFT(x)

# Plotting the input and DFT
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.stem(x, use_line_collection=True)
plt.title('Input Signal')
plt.xlabel('Sample')
plt.ylabel('Amplitude')

plt.subplot(1, 2, 2)
plt.stem(np.abs(X), use_line_collection=True)
plt.title('DFT of the Signal')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')

plt.tight_layout()
plt.show()
# Out:
# Enter the number of elements: 4
# Enter the elements:
# 1
# 2
# 3
# 4
# <ipython-input-1-6e3bdc25148c>:27: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, use_line_collection=True)
# <ipython-input-1-6e3bdc25148c>:33: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(np.abs(X), use_line_collection=True)

# %%
import numpy as np
import matplotlib.pyplot as plt

def DFT(x):
    """Compute the discrete Fourier Transform of the 1D array x"""
    N = len(x)
    X = np.zeros(N, dtype=complex)
    for k in range(N):
        for n in range(N):
            X[k] += x[n] * np.exp(-2j * np.pi * k * n / N)
    return X

# Get input from the user
n = int(input("Enter the number of elements: "))
x = []
print("Enter the elements:")
for i in range(n):
  temp = int(input())
  x.append(temp)

x = np.array(x)
X = DFT(x)

# Plotting the input and DFT
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.stem(x, use_line_collection=True)
plt.title('Input Signal')
plt.xlabel('Sample')
plt.ylabel('Amplitude')

plt.subplot(1, 2, 2)
plt.stem(np.abs(X), use_line_collection=True)
plt.title('DFT of the Signal')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')

plt.tight_layout()
plt.show()
# Out:
# Enter the number of elements: 8
# Enter the elements:
# 5
# 3
# 1
# 6
# 4
# 3
# 6
# 2
# <ipython-input-3-6e3bdc25148c>:27: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, use_line_collection=True)
# <ipython-input-3-6e3bdc25148c>:33: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(np.abs(X), use_line_collection=True)
